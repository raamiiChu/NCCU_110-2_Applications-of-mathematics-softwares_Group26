# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### <font color=#FF3030>先把csv檔上傳後，再去執行之後的程式碼</font>

# %%
location = "tw"

# %%
df_train = pd.read_csv(f"{location}_train.csv", index_col=0)
df_test = pd.read_csv(f"{location}_test.csv", index_col=0)
df_valid = pd.read_csv(f"{location}_valid.csv", index_col=0)

# %%
df_train
# Out:
#                                  path         sentence  language
# 0     common_voice_zh-TW_20290066.mp3        大家可以公開的下載         0
# 1     common_voice_zh-TW_20290078.mp3             洗洗睡了         0
# 2     common_voice_zh-TW_20290080.mp3         不好說，不好說阿         0
# 3     common_voice_zh-TW_20290111.mp3      才是女性每天面對的現實         0
# 4     common_voice_zh-TW_20290115.mp3       實際作道路供公眾通行         0
# ...                               ...              ...       ...
# 6388  common_voice_zh-TW_30243179.mp3        高雄市公車一心幹線         0
# 6389  common_voice_zh-TW_30243185.mp3              花壇端         0
# 6390  common_voice_zh-TW_30243186.mp3              新光路         0
# 6391  common_voice_zh-TW_30243188.mp3          臺北捷運環狀線         0
# 6392  common_voice_zh-TW_20127150.mp3  如果你也有興趣，歡迎一同選購。         0
#
# [6393 rows x 3 columns]

# %%
df_test
# Out:
#                                  path     sentence  language
# 0     common_voice_zh-TW_31210486.mp3    高鐵聯外公路嘉義段         0
# 1     common_voice_zh-TW_30534333.mp3     沒有要讓人看清楚         0
# 2     common_voice_zh-TW_31250509.mp3      日式照燒豬排飯         0
# 3     common_voice_zh-TW_31149482.mp3  台北捷運淡海線先導公車         0
# 4     common_voice_zh-TW_18500863.mp3       在黑暗中進行         0
# ...                               ...          ...       ...
# 4613  common_voice_zh-TW_19506895.mp3         跳樓事件         0
# 4614  common_voice_zh-TW_19506896.mp3    很多人都是當了父母         0
# 4615  common_voice_zh-TW_19506897.mp3         投入試種         0
# 4616  common_voice_zh-TW_18621956.mp3        籌備會委員         0
# 4617  common_voice_zh-TW_18621985.mp3    今天第一次籌備會議         0
#
# [4618 rows x 3 columns]

# %%
df_valid
# Out:
#                                  path     sentence  language
# 0     common_voice_zh-TW_17460387.mp3      主要概念就是要         0
# 1     common_voice_zh-TW_17460391.mp3       買了生巧克力         0
# 2     common_voice_zh-TW_17460401.mp3      不得以逃到台北         0
# 3     common_voice_zh-TW_17460403.mp3      在車上全身是汗         0
# 4     common_voice_zh-TW_17460404.mp3    當然只能買最便宜的         0
# ...                               ...          ...       ...
# 4613  common_voice_zh-TW_17405052.mp3       十分瞧不起他         0
# 4614  common_voice_zh-TW_17405054.mp3   你曾說過害怕回到當初         0
# 4615  common_voice_zh-TW_17405107.mp3  這是我十年來的研究成果         0
# 4616  common_voice_zh-TW_17428812.mp3      資金管理等技術         0
# 4617  common_voice_zh-TW_17429159.mp3      愚民就是被收割         0
#
# [4618 rows x 3 columns]
